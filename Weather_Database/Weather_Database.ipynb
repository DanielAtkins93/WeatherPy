# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=06b3dea15fd5b8ded33a69d91a256dc6

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | burica
# City not found. Skipping...
# Processing Record 3 of Set 1 | te anau
# Processing Record 4 of Set 1 | jalu
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | salinopolis
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | gorontalo
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | qasigiannguit
# Processing Record 17 of Set 1 | ormara
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | chintamani
# Processing Record 20 of Set 1 | tahlequah
# Processing Record 21 of Set 1 | henties bay
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | fairbanks
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | bhubaneswar
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | richards bay
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | torbay
# Processing Record 40 of Set 1 | husavik
# Processing Record 41 of Set 1 | vostok
# Processing Record 42 of Set 1 | parksville
# Processing Record 43 of Set 1 | shubarshi
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 1 | quixeramobim
# Processing Record 1 of Set 2 | roald
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | matamoros
# Processing Record 4 of Set 2 | pueblo nuevo
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | burnie
# Processing Record 8 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 2 | susanville
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | coos bay
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | lower hutt
# Processing Record 17 of Set 2 | galashki
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | sur
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | jelgava
# Processing Record 22 of Set 2 | kosh-agach
# Processing Record 23 of Set 2 | areosa
# Processing Record 24 of Set 2 | ust-maya
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | abalak
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | kefalos
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | mindelo
# Processing Record 33 of Set 2 | high river
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | jinchang
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | maumere
# Processing Record 38 of Set 2 | katherine
# Processing Record 39 of Set 2 | santa cecilia
# Processing Record 40 of Set 2 | roseburg
# Processing Record 41 of Set 2 | nuevitas
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | nemuro
# Processing Record 46 of Set 2 | dwarka
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | turayf
# Processing Record 3 of Set 3 | esperance
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | moindou
# Processing Record 7 of Set 3 | berlevag
# Processing Record 8 of Set 3 | bubaque
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | toora-khem
# Processing Record 11 of Set 3 | thinadhoo
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | moanda
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | akdepe
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | kilchberg
# Processing Record 20 of Set 3 | chabahar
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | vaitape
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | gizo
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | porto novo
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | tsabong
# Processing Record 30 of Set 3 | arkhangelsk
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | kontagora
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | kollegal
# Processing Record 35 of Set 3 | puerto ayora
# Processing Record 36 of Set 3 | bedum
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | soc trang
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | medina del campo
# Processing Record 42 of Set 3 | goderich
# Processing Record 43 of Set 3 | puertollano
# Processing Record 44 of Set 3 | eureka
# Processing Record 45 of Set 3 | kuala terengganu
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | palmer
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | muros
# Processing Record 1 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 4 | san luis
# Processing Record 3 of Set 4 | macapa
# Processing Record 4 of Set 4 | sampit
# Processing Record 5 of Set 4 | derzhavinsk
# Processing Record 6 of Set 4 | ikom
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 4 | jiuquan
# Processing Record 10 of Set 4 | ust-kuyga
# Processing Record 11 of Set 4 | kapaa
# Processing Record 12 of Set 4 | santa luzia
# Processing Record 13 of Set 4 | arequipa
# Processing Record 14 of Set 4 | chuy
# Processing Record 15 of Set 4 | acari
# Processing Record 16 of Set 4 | mao
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | bandarbeyla
# Processing Record 21 of Set 4 | kismayo
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | san felipe
# Processing Record 24 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | frontera
# Processing Record 27 of Set 4 | terney
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | kolyvan
# Processing Record 30 of Set 4 | upata
# Processing Record 31 of Set 4 | chum phae
# Processing Record 32 of Set 4 | vestmannaeyjar
# Processing Record 33 of Set 4 | bouloupari
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | kijang
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | sibolga
# Processing Record 40 of Set 4 | curuguaty
# Processing Record 41 of Set 4 | kirakira
# Processing Record 42 of Set 4 | la macarena
# Processing Record 43 of Set 4 | dingle
# Processing Record 44 of Set 4 | pathein
# Processing Record 45 of Set 4 | dzilam gonzalez
# Processing Record 46 of Set 4 | conceicao da barra
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | bredasdorp
# Processing Record 50 of Set 4 | makakilo city
# Processing Record 1 of Set 5 | acapulco
# Processing Record 2 of Set 5 | waitati
# Processing Record 3 of Set 5 | moyo
# Processing Record 4 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 5 | ballina
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | clyde river
# Processing Record 8 of Set 5 | mahajanga
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | bobrovka
# Processing Record 12 of Set 5 | inzer
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | irtyshskiy
# Processing Record 17 of Set 5 | kalmunai
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | kaeo
# Processing Record 20 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 21 of Set 5 | anadyr
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | liwale
# Processing Record 24 of Set 5 | itarema
# Processing Record 25 of Set 5 | chake chake
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | porto nacional
# Processing Record 28 of Set 5 | moranbah
# Processing Record 29 of Set 5 | fomboni
# Processing Record 30 of Set 5 | meulaboh
# Processing Record 31 of Set 5 | renala khurd
# Processing Record 32 of Set 5 | qinhuangdao
# Processing Record 33 of Set 5 | kisangani
# Processing Record 34 of Set 5 | methoni
# Processing Record 35 of Set 5 | safaga
# Processing Record 36 of Set 5 | xinxiang
# Processing Record 37 of Set 5 | umm lajj
# Processing Record 38 of Set 5 | alta floresta
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | labuhan
# Processing Record 41 of Set 5 | vestnes
# Processing Record 42 of Set 5 | manggar
# Processing Record 43 of Set 5 | hervey bay
# Processing Record 44 of Set 5 | jizan
# Processing Record 45 of Set 5 | novoagansk
# Processing Record 46 of Set 5 | namwala
# Processing Record 47 of Set 5 | madimba
# Processing Record 48 of Set 5 | zhigansk
# Processing Record 49 of Set 5 | zacualpan
# Processing Record 50 of Set 5 | flinders
# Processing Record 1 of Set 6 | taltal
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | gunnedah
# Processing Record 4 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | hammerfest
# Processing Record 6 of Set 6 | vaasa
# Processing Record 7 of Set 6 | lae
# Processing Record 8 of Set 6 | chapleau
# Processing Record 9 of Set 6 | progreso
# Processing Record 10 of Set 6 | mahebourg
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | bandrele
# Processing Record 14 of Set 6 | deputatskiy
# Processing Record 15 of Set 6 | douentza
# Processing Record 16 of Set 6 | biak
# Processing Record 17 of Set 6 | bethel
# Processing Record 18 of Set 6 | pimentel
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | senneterre
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | fort nelson
# Processing Record 24 of Set 6 | aguadilla
# Processing Record 25 of Set 6 | banda aceh
# Processing Record 26 of Set 6 | yairipok
# Processing Record 27 of Set 6 | abengourou
# Processing Record 28 of Set 6 | myaundzha
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | giddarbaha
# Processing Record 31 of Set 6 | mataram
# Processing Record 32 of Set 6 | holguin
# Processing Record 33 of Set 6 | maraa
# Processing Record 34 of Set 6 | huanren
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | itoman
# Processing Record 37 of Set 6 | cabras
# Processing Record 38 of Set 6 | sambava
# Processing Record 39 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 40 of Set 6 | katangli
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 6 | namtsy
# Processing Record 43 of Set 6 | martinsicuro
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | fuyang
# Processing Record 46 of Set 6 | awbari
# Processing Record 47 of Set 6 | la seyne-sur-mer
# Processing Record 48 of Set 6 | rabo de peixe
# Processing Record 49 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 6 | sinnai
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | camalu
# Processing Record 3 of Set 7 | bilibino
# Processing Record 4 of Set 7 | severo-yeniseyskiy
# Processing Record 5 of Set 7 | noumea
# Processing Record 6 of Set 7 | port hedland
# Processing Record 7 of Set 7 | blaj
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | riviere-au-renard
# Processing Record 10 of Set 7 | shingu
# Processing Record 11 of Set 7 | assiniboia
# Processing Record 12 of Set 7 | sangar
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | acarau
# Processing Record 15 of Set 7 | sindor
# Processing Record 16 of Set 7 | hailar
# Processing Record 17 of Set 7 | portoferraio
# Processing Record 18 of Set 7 | khandyga
# Processing Record 19 of Set 7 | nalgonda
# Processing Record 20 of Set 7 | kaitangata
# Processing Record 21 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 23 of Set 7 | busayra
# Processing Record 24 of Set 7 | varhaug
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 27 of Set 7 | sinnamary
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 7 | nagua
# Processing Record 31 of Set 7 | barra patuca
# Processing Record 32 of Set 7 | buala
# Processing Record 33 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 7 | auki
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | gilbues
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | makat
# Processing Record 39 of Set 7 | tiksi
# Processing Record 40 of Set 7 | xining
# Processing Record 41 of Set 7 | yunhe
# Processing Record 42 of Set 7 | mulchen
# Processing Record 43 of Set 7 | miquelon
# Processing Record 44 of Set 7 | broken hill
# Processing Record 45 of Set 7 | north bend
# Processing Record 46 of Set 7 | aksu
# Processing Record 47 of Set 7 | opportunity
# Processing Record 48 of Set 7 | cookeville
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 1 of Set 8 | mouzakion
# City not found. Skipping...
# Processing Record 2 of Set 8 | quatre cocos
# Processing Record 3 of Set 8 | butaritari
# Processing Record 4 of Set 8 | northam
# Processing Record 5 of Set 8 | tuy hoa
# Processing Record 6 of Set 8 | kulhudhuffushi
# Processing Record 7 of Set 8 | hay river
# Processing Record 8 of Set 8 | dongsheng
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | tilichiki
# Processing Record 12 of Set 8 | bratsk
# Processing Record 13 of Set 8 | berdigestyakh
# Processing Record 14 of Set 8 | kuruman
# Processing Record 15 of Set 8 | garowe
# Processing Record 16 of Set 8 | ancud
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | manokwari
# Processing Record 19 of Set 8 | pischia
# Processing Record 20 of Set 8 | touros
# Processing Record 21 of Set 8 | todos santos
# Processing Record 22 of Set 8 | ishigaki
# Processing Record 23 of Set 8 | charlestown
# Processing Record 24 of Set 8 | zabol
# Processing Record 25 of Set 8 | fort dodge
# Processing Record 26 of Set 8 | merauke
# Processing Record 27 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 28 of Set 8 | semnan
# Processing Record 29 of Set 8 | stepnogorsk
# Processing Record 30 of Set 8 | santiago del estero
# Processing Record 31 of Set 8 | bagepalli
# Processing Record 32 of Set 8 | collie
# Processing Record 33 of Set 8 | ippy
# Processing Record 34 of Set 8 | tula
# Processing Record 35 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | strenci
# Processing Record 37 of Set 8 | edinburg
# Processing Record 38 of Set 8 | coruripe
# Processing Record 39 of Set 8 | nanortalik
# Processing Record 40 of Set 8 | gambita
# City not found. Skipping...
# Processing Record 41 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | lerwick
# Processing Record 44 of Set 8 | lavrentiya
# Processing Record 45 of Set 8 | west bay
# Processing Record 46 of Set 8 | lufilufi
# Processing Record 47 of Set 8 | yeppoon
# Processing Record 48 of Set 8 | brazzaville
# Processing Record 49 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | peleduy
# Processing Record 2 of Set 9 | ust-nera
# Processing Record 3 of Set 9 | kattivakkam
# Processing Record 4 of Set 9 | kodinsk
# Processing Record 5 of Set 9 | yar
# Processing Record 6 of Set 9 | paamiut
# Processing Record 7 of Set 9 | shaunavon
# Processing Record 8 of Set 9 | denpasar
# Processing Record 9 of Set 9 | la tuque
# Processing Record 10 of Set 9 | helong
# Processing Record 11 of Set 9 | bentiu
# Processing Record 12 of Set 9 | parabel
# Processing Record 13 of Set 9 | cidreira
# Processing Record 14 of Set 9 | waingapu
# Processing Record 15 of Set 9 | mogadishu
# Processing Record 16 of Set 9 | verkhoyansk
# Processing Record 17 of Set 9 | sansai
# City not found. Skipping...
# Processing Record 18 of Set 9 | visnes
# Processing Record 19 of Set 9 | marawi
# Processing Record 20 of Set 9 | bobrovskiy
# Processing Record 21 of Set 9 | puerto baquerizo moreno
# Processing Record 22 of Set 9 | demba
# Processing Record 23 of Set 9 | igaracu do tiete
# Processing Record 24 of Set 9 | batagay
# Processing Record 25 of Set 9 | san policarpo
# Processing Record 26 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 9 | williams lake
# Processing Record 29 of Set 9 | xudat
# Processing Record 30 of Set 9 | sisimiut
# Processing Record 31 of Set 9 | kainantu
# Processing Record 32 of Set 9 | brigantine
# Processing Record 33 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 9 | tay ninh
# Processing Record 37 of Set 9 | mountain home
# Processing Record 38 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 9 | bay roberts
# Processing Record 40 of Set 9 | luderitz
# Processing Record 41 of Set 9 | teya
# Processing Record 42 of Set 9 | roma
# Processing Record 43 of Set 9 | tangzhai
# Processing Record 44 of Set 9 | bara
# Processing Record 45 of Set 9 | mtambile
# Processing Record 46 of Set 9 | gaoua
# Processing Record 47 of Set 9 | amarillo
# Processing Record 48 of Set 9 | yartsevo
# Processing Record 49 of Set 9 | nha trang
# Processing Record 50 of Set 9 | xiaolingwei
# Processing Record 1 of Set 10 | morant bay
# Processing Record 2 of Set 10 | vao
# Processing Record 3 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 10 | quebo
# Processing Record 5 of Set 10 | santa cruz
# Processing Record 6 of Set 10 | cockburn town
# Processing Record 7 of Set 10 | shizunai
# Processing Record 8 of Set 10 | les cayes
# Processing Record 9 of Set 10 | de aar
# Processing Record 10 of Set 10 | vondrozo
# Processing Record 11 of Set 10 | iskateley
# Processing Record 12 of Set 10 | coahuayana
# Processing Record 13 of Set 10 | alihe
# Processing Record 14 of Set 10 | bodaybo
# Processing Record 15 of Set 10 | viedma
# Processing Record 16 of Set 10 | piacabucu
# Processing Record 17 of Set 10 | tumbi
# Processing Record 18 of Set 10 | hovsan
# Processing Record 19 of Set 10 | brownsville
# Processing Record 20 of Set 10 | waipawa
# Processing Record 21 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 22 of Set 10 | mayo
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | limbang
# Processing Record 25 of Set 10 | matadi
# Processing Record 26 of Set 10 | krutinka
# Processing Record 27 of Set 10 | narsaq
# Processing Record 28 of Set 10 | laredo
# Processing Record 29 of Set 10 | chapais
# Processing Record 30 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 10 | the valley
# Processing Record 32 of Set 10 | baiyin
# Processing Record 33 of Set 10 | manta
# Processing Record 34 of Set 10 | kokopo
# Processing Record 35 of Set 10 | dese
# Processing Record 36 of Set 10 | pochutla
# Processing Record 37 of Set 10 | beloha
# Processing Record 38 of Set 10 | kollam
# Processing Record 39 of Set 10 | mahe
# Processing Record 40 of Set 10 | alekseyevka
# Processing Record 41 of Set 10 | sabang
# Processing Record 42 of Set 10 | aitape
# Processing Record 43 of Set 10 | ahipara
# Processing Record 44 of Set 10 | odweyne
# Processing Record 45 of Set 10 | sao filipe
# Processing Record 46 of Set 10 | nefteyugansk
# Processing Record 47 of Set 10 | batemans bay
# Processing Record 48 of Set 10 | klaksvik
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | maragogi
# Processing Record 1 of Set 11 | senador jose porfirio
# Processing Record 2 of Set 11 | boyuibe
# Processing Record 3 of Set 11 | ponta delgada
# Processing Record 4 of Set 11 | suba
# Processing Record 5 of Set 11 | zhezkazgan
# Processing Record 6 of Set 11 | mundo nuevo
# Processing Record 7 of Set 11 | catamarca
# Processing Record 8 of Set 11 | benghazi
# Processing Record 9 of Set 11 | sorland
# Processing Record 10 of Set 11 | floro
# Processing Record 11 of Set 11 | mollendo
# Processing Record 12 of Set 11 | puerto escondido
# Processing Record 13 of Set 11 | uporovo
# Processing Record 14 of Set 11 | hambantota
# Processing Record 15 of Set 11 | gigmoto
# Processing Record 16 of Set 11 | atar
# Processing Record 17 of Set 11 | ginda
# Processing Record 18 of Set 11 | bouar
# Processing Record 19 of Set 11 | margate
# Processing Record 20 of Set 11 | uyutne
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | somerset east
# Processing Record 23 of Set 11 | aklavik
# Processing Record 24 of Set 11 | bjornevatn
# Processing Record 25 of Set 11 | kindu
# Processing Record 26 of Set 11 | jatai
# Processing Record 27 of Set 11 | puerto del rosario
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | san pedro
# Processing Record 30 of Set 11 | general pico
# Processing Record 31 of Set 11 | riyadh
# Processing Record 32 of Set 11 | monduli
# Processing Record 33 of Set 11 | mpulungu
# Processing Record 34 of Set 11 | naryan-mar
# Processing Record 35 of Set 11 | katsuura
# Processing Record 36 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 11 | kidal
# Processing Record 38 of Set 11 | grodzisk wielkopolski
# Processing Record 39 of Set 11 | phalaborwa
# Processing Record 40 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | shu
# Processing Record 43 of Set 11 | port moresby
# Processing Record 44 of Set 11 | baturaja
# Processing Record 45 of Set 11 | kosino
# Processing Record 46 of Set 11 | bud
# Processing Record 47 of Set 11 | fuling
# Processing Record 48 of Set 11 | wolmaranstad
# City not found. Skipping...
# Processing Record 49 of Set 11 | ketchikan
# Processing Record 50 of Set 11 | agva
# City not found. Skipping...
# Processing Record 1 of Set 12 | calabozo
# Processing Record 2 of Set 12 | havoysund
# Processing Record 3 of Set 12 | surt
# Processing Record 4 of Set 12 | angoche
# Processing Record 5 of Set 12 | madang
# Processing Record 6 of Set 12 | mount isa
# Processing Record 7 of Set 12 | olafsvik
# Processing Record 8 of Set 12 | karratha
# Processing Record 9 of Set 12 | wangjing
# Processing Record 10 of Set 12 | challapata
# Processing Record 11 of Set 12 | beni mazar
# Processing Record 12 of Set 12 | aleksandrov gay
# Processing Record 13 of Set 12 | shanghai
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | lata
# Processing Record 16 of Set 12 | zhuhai
# Processing Record 17 of Set 12 | port blair
# Processing Record 18 of Set 12 | balsas
# Processing Record 19 of Set 12 | mudgee
# Processing Record 20 of Set 12 | vung tau
# Processing Record 21 of Set 12 | moron
# Processing Record 22 of Set 12 | workington
# Processing Record 23 of Set 12 | selizharovo
# Processing Record 24 of Set 12 | saint pete beach
# Processing Record 25 of Set 12 | tymovskoye
# Processing Record 26 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 12 | rochegda
# Processing Record 28 of Set 12 | champerico
# Processing Record 29 of Set 12 | yining
# Processing Record 30 of Set 12 | gidole
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | kitimat
# Processing Record 33 of Set 12 | vila franca do campo
# Processing Record 34 of Set 12 | pangnirtung
# Processing Record 35 of Set 12 | tazmalt
# Processing Record 36 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 12 | dauphin
# Processing Record 38 of Set 12 | joensuu
# Processing Record 39 of Set 12 | trairi
# Processing Record 40 of Set 12 | itacoatiara
# Processing Record 41 of Set 12 | ambilobe
# Processing Record 42 of Set 12 | nador
# Processing Record 43 of Set 12 | odemira
# Processing Record 44 of Set 12 | kibungo
# Processing Record 45 of Set 12 | presidencia roque saenz pena
# Processing Record 46 of Set 12 | kirensk
# Processing Record 47 of Set 12 | san carlos del zulia
# Processing Record 48 of Set 12 | casper
# Processing Record 49 of Set 12 | buraydah
# Processing Record 50 of Set 12 | port shepstone
# Processing Record 1 of Set 13 | dhidhdhoo
# Processing Record 2 of Set 13 | seryshevo
# Processing Record 3 of Set 13 | paita
# Processing Record 4 of Set 13 | cayenne
# Processing Record 5 of Set 13 | nishihara
# Processing Record 6 of Set 13 | vestmanna
# Processing Record 7 of Set 13 | alice springs
# Processing Record 8 of Set 13 | san martin
# Processing Record 9 of Set 13 | wukari
# Processing Record 10 of Set 13 | sijunjung
# Processing Record 11 of Set 13 | mackenzie
# Processing Record 12 of Set 13 | houma
# Processing Record 13 of Set 13 | bilma
# Processing Record 14 of Set 13 | plettenberg bay
# Processing Record 15 of Set 13 | isla mujeres
# Processing Record 16 of Set 13 | bajil
# Processing Record 17 of Set 13 | mixtequilla
# City not found. Skipping...
# Processing Record 18 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 13 | westerland
# Processing Record 20 of Set 13 | sherbakul
# Processing Record 21 of Set 13 | sola
# Processing Record 22 of Set 13 | grong
# Processing Record 23 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 24 of Set 13 | lagunas
# Processing Record 25 of Set 13 | rantepao
# Processing Record 26 of Set 13 | berbera
# Processing Record 27 of Set 13 | egvekinot
# Processing Record 28 of Set 13 | hobyo
# Processing Record 29 of Set 13 | skjervoy
# Processing Record 30 of Set 13 | shar
# Processing Record 31 of Set 13 | alofi
# Processing Record 32 of Set 13 | comodoro rivadavia
# Processing Record 33 of Set 13 | king city
# Processing Record 34 of Set 13 | russell
# Processing Record 35 of Set 13 | cuamba
# Processing Record 36 of Set 13 | ahuimanu
# Processing Record 37 of Set 13 | ocean city
# Processing Record 38 of Set 13 | nieuw amsterdam
# Processing Record 39 of Set 13 | jacupiranga
# Processing Record 40 of Set 13 | hongjiang
# Processing Record 41 of Set 13 | pasni
# Processing Record 42 of Set 13 | mizan teferi
# Processing Record 43 of Set 13 | qabis
# City not found. Skipping...
# Processing Record 44 of Set 13 | okha
# Processing Record 45 of Set 13 | berikulskiy
# City not found. Skipping...
# Processing Record 46 of Set 13 | inuvik
# Processing Record 47 of Set 13 | hualmay
# Processing Record 48 of Set 13 | stromness
# Processing Record 49 of Set 13 | agua verde
# Processing Record 50 of Set 13 | marzuq
# Processing Record 1 of Set 14 | axim
# Processing Record 2 of Set 14 | masvingo
# Processing Record 3 of Set 14 | voznesenye
# Processing Record 4 of Set 14 | kabo
# Processing Record 5 of Set 14 | alyangula
# Processing Record 6 of Set 14 | shahr-e babak
# Processing Record 7 of Set 14 | canutama
# Processing Record 8 of Set 14 | sabha
# Processing Record 9 of Set 14 | coolum beach
# Processing Record 10 of Set 14 | soloneshnoye
# Processing Record 11 of Set 14 | atyrau
# Processing Record 12 of Set 14 | harper
# Processing Record 13 of Set 14 | lasa
# Processing Record 14 of Set 14 | balabac
# Processing Record 15 of Set 14 | haines junction
# Processing Record 16 of Set 14 | kadyy
# Processing Record 17 of Set 14 | tautira
# Processing Record 18 of Set 14 | caxito
# Processing Record 19 of Set 14 | kropotkin
# Processing Record 20 of Set 14 | urumqi
# Processing Record 21 of Set 14 | ulaangom
# Processing Record 22 of Set 14 | ayan
# Processing Record 23 of Set 14 | asifabad
# Processing Record 24 of Set 14 | marathon
# Processing Record 25 of Set 14 | sembe
# Processing Record 26 of Set 14 | amga
# Processing Record 27 of Set 14 | bonthe
# Processing Record 28 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 29 of Set 14 | podkletnoye
# Processing Record 30 of Set 14 | rawson
# Processing Record 31 of Set 14 | broome
# Processing Record 32 of Set 14 | goure
# Processing Record 33 of Set 14 | sao joao da barra
# Processing Record 34 of Set 14 | coihaique
# Processing Record 35 of Set 14 | bar-le-duc
# Processing Record 36 of Set 14 | boralday
# Processing Record 37 of Set 14 | ossora
# Processing Record 38 of Set 14 | vanderhoof
# Processing Record 39 of Set 14 | tessalit
# Processing Record 40 of Set 14 | byron bay
# Processing Record 41 of Set 14 | jambi
# Processing Record 42 of Set 14 | mbigou
# Processing Record 43 of Set 14 | general roca
# Processing Record 44 of Set 14 | chicama
# Processing Record 45 of Set 14 | batsfjord
# Processing Record 46 of Set 14 | lethem
# Processing Record 47 of Set 14 | mayumba
# Processing Record 48 of Set 14 | baker city
# Processing Record 49 of Set 14 | valdez
# Processing Record 50 of Set 14 | fuerte
# Processing Record 1 of Set 15 | rehoboth
# Processing Record 2 of Set 15 | fengzhen
# Processing Record 3 of Set 15 | erzin
# Processing Record 4 of Set 15 | nishiwaki
# Processing Record 5 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 15 | veraval
# Processing Record 7 of Set 15 | xinye
# Processing Record 8 of Set 15 | beitbridge
# Processing Record 9 of Set 15 | aykhal
# Processing Record 10 of Set 15 | staryy biser
# City not found. Skipping...
# Processing Record 11 of Set 15 | anloga
# Processing Record 12 of Set 15 | victor harbor
# Processing Record 13 of Set 15 | kasangulu
# Processing Record 14 of Set 15 | myrtle beach
# Processing Record 15 of Set 15 | katobu
# Processing Record 16 of Set 15 | cairns
# Processing Record 17 of Set 15 | naze
# Processing Record 18 of Set 15 | anaconda
# Processing Record 19 of Set 15 | babanka
# Processing Record 20 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 15 | matay
# Processing Record 22 of Set 15 | vardo
# Processing Record 23 of Set 15 | san quintin
# Processing Record 24 of Set 15 | tsumeb
# Processing Record 25 of Set 15 | skiathos
# Processing Record 26 of Set 15 | umm kaddadah
# Processing Record 27 of Set 15 | saint-joseph
# Processing Record 28 of Set 15 | raga
# Processing Record 29 of Set 15 | amahai
# Processing Record 30 of Set 15 | ca mau
# Processing Record 31 of Set 15 | bukama
# Processing Record 32 of Set 15 | saint anthony
# Processing Record 33 of Set 15 | turukhansk
# Processing Record 34 of Set 15 | brainerd
# Processing Record 35 of Set 15 | uusikaupunki
# Processing Record 36 of Set 15 | le port
# Processing Record 37 of Set 15 | conde
# Processing Record 38 of Set 15 | kerman
# Processing Record 39 of Set 15 | ust-kulom
# Processing Record 40 of Set 15 | port augusta
# Processing Record 41 of Set 15 | hamilton
# Processing Record 42 of Set 15 | bolshaya glushitsa
# Processing Record 43 of Set 15 | brae
# Processing Record 44 of Set 15 | kovdor
# Processing Record 45 of Set 15 | suntar
# Processing Record 46 of Set 15 | lieksa
# Processing Record 47 of Set 15 | shyroke
# Processing Record 48 of Set 15 | bulle
# Processing Record 49 of Set 15 | bafoulabe
# Processing Record 50 of Set 15 | balykshi
# Processing Record 1 of Set 16 | ola
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ushuaia -54.8000  -68.3000     40.66        70          75       21.85
# 1      Te Anau -45.4167  167.7167     53.08        65         100        3.27
# 2         Jalu  29.0331   21.5482     60.30        72          97        6.71
# 3      Rikitea -23.1203 -134.9692     73.90        76         100        8.88
# 4       Faanui -16.4833 -151.7500     79.00        72          29       15.14
# 5       Barrow  71.2906 -156.7887      8.62        78         100       18.41
# 6  Salinopolis  -0.6136  -47.3561     80.47        76         100       11.68
# 7   Georgetown   5.4112  100.3354     80.53        91          20        2.30
# 8    Gorontalo   0.5412  123.0595     86.49        65          89        0.98
# 9      Mataura -46.1927  168.8643     54.48        47         100        8.10
#
#   Country Current Description
# 0      AR       broken clouds
# 1      NZ     overcast clouds
# 2      LY     overcast clouds
# 3      PF     overcast clouds
# 4      PF    scattered clouds
# 5      US          light snow
# 6      BR     overcast clouds
# 7      MY          few clouds
# 8      ID     overcast clouds
# 9      NZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia      AR -54.8000  -68.3000     40.66        70          75
# 1      Te Anau      NZ -45.4167  167.7167     53.08        65         100
# 2         Jalu      LY  29.0331   21.5482     60.30        72          97
# 3      Rikitea      PF -23.1203 -134.9692     73.90        76         100
# 4       Faanui      PF -16.4833 -151.7500     79.00        72          29
# 5       Barrow      US  71.2906 -156.7887      8.62        78         100
# 6  Salinopolis      BR  -0.6136  -47.3561     80.47        76         100
# 7   Georgetown      MY   5.4112  100.3354     80.53        91          20
# 8    Gorontalo      ID   0.5412  123.0595     86.49        65          89
# 9      Mataura      NZ -46.1927  168.8643     54.48        47         100
#
#    Wind Speed Current Description
# 0       21.85       broken clouds
# 1        3.27     overcast clouds
# 2        6.71     overcast clouds
# 3        8.88     overcast clouds
# 4       15.14    scattered clouds
# 5       18.41          light snow
# 6       11.68     overcast clouds
# 7        2.30          few clouds
# 8        0.98     overcast clouds
# 9        8.10     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
